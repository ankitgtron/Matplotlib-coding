# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x= [1,2,3,4,5,6,7]
y = [50,51,48,49,52,53,47]

# %%
plt.plot(x, y, color = 'red', linewidth = 6, linestyle = 'dashed')
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title("Weather")
# Out:
# Text(0.5, 1.0, 'Weather')
